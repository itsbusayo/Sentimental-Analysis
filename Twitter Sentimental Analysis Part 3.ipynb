# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('Trained Twitter Sentimental Analysis Data.csv')

# %%
df
# Out:
#        Unnamed: 0                   Datetime             Tweet Id  \
# 0               0  2022-01-30 23:38:14+00:00  1487933203809714177
# 1               1  2022-01-30 22:34:47+00:00  1487917234106339330
# 2               2  2022-01-30 22:23:50+00:00  1487914477521674244
# 3               3  2022-01-30 22:14:08+00:00  1487912038026420225
# 4               4  2022-01-30 22:02:11+00:00  1487909028588142596
# ...           ...                        ...                  ...
# 15681       15711  2021-10-01 09:26:58+00:00  1443870040529555488
# 15682       15712  2021-10-01 07:49:07+00:00  1443845418614358023
# 15683       15713  2021-10-01 07:37:44+00:00  1443842551455223812
# 15684       15714  2021-10-01 04:07:04+00:00  1443789538619494401
# 15685       15715  2021-10-01 01:04:08+00:00  1443743501515165698
#
#                                                     Text         Username  \
# 0      Dear Mr president Muhammadu Buhari, please han...     ismailmsani4
# ...

# %%
df_New = df.dropna()

# %%
df_New
# Out:
#        Unnamed: 0                   Datetime             Tweet Id  \
# 0               0  2022-01-30 23:38:14+00:00  1487933203809714177
# 1               1  2022-01-30 22:34:47+00:00  1487917234106339330
# 2               2  2022-01-30 22:23:50+00:00  1487914477521674244
# 3               3  2022-01-30 22:14:08+00:00  1487912038026420225
# 4               4  2022-01-30 22:02:11+00:00  1487909028588142596
# ...           ...                        ...                  ...
# 15680       15710  2021-10-01 10:28:02+00:00  1443885410782941191
# 15682       15712  2021-10-01 07:49:07+00:00  1443845418614358023
# 15683       15713  2021-10-01 07:37:44+00:00  1443842551455223812
# 15684       15714  2021-10-01 04:07:04+00:00  1443789538619494401
# 15685       15715  2021-10-01 01:04:08+00:00  1443743501515165698
#
#                                                     Text         Username  \
# 0      Dear Mr president Muhammadu Buhari, please han...     ismailmsani4
# ...

# %%
# See quick results of the Sentiment Analysis
df_New['Sentiment'].value_counts()
# Out:
# Neutral     7857
# Positive    5225
# Negative    2201
# Name: Sentiment, dtype: int64

# %%
df_New.Sentiment.value_counts().plot(kind='bar',title="Distribution of Sentiment Analysis");

# %%
# Support Vector Machine

label=df_New[['Sentiment Values']].values

features=df_New[['Processed_Tweets']]

from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer=TfidfVectorizer(analyzer="word",lowercase=True)
sentence_train_vector=vectorizer.fit_transform(df_New.iloc[:,5].astype(str))

features=sentence_train_vector

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features,label,test_size=0.50,random_state=0)

from sklearn.svm import SVC
svc=SVC(kernel='rbf')
svc.fit(x_train,y_train)
result=svc.predict(x_test)

from sklearn.metrics import confusion_matrix 
cm=confusion_matrix(y_test,result)
print(cm)

from sklearn.metrics import accuracy_score,classification_report
accuracy=accuracy_score(y_test,result)
print(accuracy)

print(classification_report(y_test,result))
# Out:
# C:\Users\HP\anaconda3\anaconda 3.8\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [[ 584  415  117]
#  [   1 3883   44]
#  [  29  571 1998]]
# 0.8459827270348076
#               precision    recall  f1-score   support
#
#           -1       0.95      0.52      0.68      1116
#            0       0.80      0.99      0.88      3928
#            1       0.93      0.77      0.84      2598
#
#     accuracy                           0.85      7642
#    macro avg       0.89      0.76      0.80      7642
# weighted avg       0.86      0.85      0.84      7642

# %%
# Naive Bayes

species=df[['Sentiment Values']].values

from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer=TfidfVectorizer(analyzer="word",lowercase=True)
sentence_train_vector=vectorizer.fit_transform(df.iloc[:,5].astype(str)).toarray()

a=sentence_train_vector

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(a,species,test_size=0.50,random_state=0)

from sklearn.naive_bayes import GaussianNB

gnb=GaussianNB()

gnb.fit(x_train, y_train.ravel())

result=gnb.predict(x_test)

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,result)
print(cm)

from sklearn.metrics import accuracy_score,classification_report
accuarcy=accuracy_score(y_test,result)
print((accuarcy*100), '%')

print(classification_report(y_test,result))
# Out:
# [[ 743  119  251]
#  [1775 2006  360]
#  [ 729  286 1574]]
# 55.11921458625526 %
#               precision    recall  f1-score   support
#
#           -1       0.23      0.67      0.34      1113
#            0       0.83      0.48      0.61      4141
#            1       0.72      0.61      0.66      2589
#
#     accuracy                           0.55      7843
#    macro avg       0.59      0.59      0.54      7843
# weighted avg       0.71      0.55      0.59      7843

# %%
#K NEAREST NEIGHBOUR

label=df[['Sentiment Values']].values

features=df[['Processed_Tweets']]

from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer=TfidfVectorizer(analyzer="word",lowercase=True)
sentence_train_vector=vectorizer.fit_transform(df.iloc[:,5].astype(str))

features=sentence_train_vector


from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features,label,test_size=0.50,random_state=0)

from sklearn.neighbors import KNeighborsClassifier
Knn = KNeighborsClassifier(n_neighbors=5)
Knn.fit(x_train, y_train)

predictions = Knn.predict(x_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
print(accuracy_score(y_test, predictions))
# Out:
# C:\Users\HP\anaconda3\anaconda 3.8\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# [[ 504  525   84]
#  [  72 3858  211]
#  [  88 1235 1266]]
#               precision    recall  f1-score   support
#
#           -1       0.76      0.45      0.57      1113
#            0       0.69      0.93      0.79      4141
#            1       0.81      0.49      0.61      2589
#
#     accuracy                           0.72      7843
#    macro avg       0.75      0.62      0.66      7843
# weighted avg       0.74      0.72      0.70      7843
#
# 0.7175825576947596

# %%
#Logistic Regression

label=df[['Sentiment Values']].values

features=df[['Processed_Tweets']]

from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer=TfidfVectorizer(analyzer="word",lowercase=True)
sentence_train_vector=vectorizer.fit_transform(df.iloc[:,5].astype(str))



from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(sentence_train_vector,label,test_size=0.50,random_state=0)

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, y_train)

predictions = lr.predict(x_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
print(accuracy_score(y_test, predictions))
# Out:
# C:\Users\HP\anaconda3\anaconda 3.8\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [[ 545  423  145]
#  [  10 4037   94]
#  [  35  481 2073]]
#               precision    recall  f1-score   support
#
#           -1       0.92      0.49      0.64      1113
#            0       0.82      0.97      0.89      4141
#            1       0.90      0.80      0.85      2589
#
#     accuracy                           0.85      7843
#    macro avg       0.88      0.76      0.79      7843
# weighted avg       0.86      0.85      0.84      7843
#
# 0.8485273492286115

# %%
# Ensembling Methods
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(sentence_train_vector,label,test_size=0.50,random_state=0)

log_clf = LogisticRegression()
svm_clf = SVC()
gnb_clf = GaussianNB()
Knn_clf = KNeighborsClassifier()

voting_clf = VotingClassifier(estimators=[('lr', log_clf),('svc', svm_clf),('nb', gnb_clf),('knn', Knn_clf)], voting='hard' )
voting_clf.fit(x_train.toarray(), y_train)
# Out:
# C:\Users\HP\anaconda3\anaconda 3.8\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# VotingClassifier(estimators=[('lr', LogisticRegression()), ('svc', SVC()),
#                              ('nb', GaussianNB()),
#                              ('knn', KNeighborsClassifier())])

# %%
# Getting the Accuracy Score, Classification Report and Confusion Matrix
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

voting_clf.fit(x_train.toarray(), y_train)
y_pred = voting_clf.predict(x_test.toarray())
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# C:\Users\HP\anaconda3\anaconda 3.8\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [[ 630  385   98]
#  [  66 4033   42]
#  [  66  623 1900]]
#               precision    recall  f1-score   support
#
#           -1       0.83      0.57      0.67      1113
#            0       0.80      0.97      0.88      4141
#            1       0.93      0.73      0.82      2589
#
#     accuracy                           0.84      7843
#    macro avg       0.85      0.76      0.79      7843
# weighted avg       0.85      0.84      0.83      7843
#
# 0.8367971439500191
